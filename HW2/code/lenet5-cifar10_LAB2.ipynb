# %% [markdown]
# # Training LeNet-5 on CIFAR-10
# In this notebook, we will try to deploy the famous LeNet-5 to solve a simple image classification task, the CIFAR-10. CIFAR-10 is composed of 60K images from 10 categories. After splitting the dataset, we have 45K/5K/10K images for train/valiation/test dataset.
# In this notebook, only the labels of training/validation dataset is visible to you, so you can use the training and validation data to tune your model. After you submitted your model, your final grade will be determined on the model performance on the holdout test dataset.

# %% [markdown]
# ### Step 0 Setting up LeNet-5 model
# As you have set up the LeNet-5 model in Homework 1, we will just move the implementation of LeNet-5 model here, so you can use it for this homework.

# %%
import argparse
import os, sys
import time
import datetime

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from tqdm import tqdm_notebook as tqdm

# %%
import math

def swish(x):
    return x * torch.sigmoid(x)
# Create the neural network module: LeNet-5
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.norm1 = nn.BatchNorm2d(6)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.norm2 = nn.BatchNorm2d(16)
        self.fc1   = nn.Linear(16*5*5, 120)
        self.norm3 = nn.BatchNorm1d(120)
        self.fc2   = nn.Linear(120, 84)
        self.norm4 = nn.BatchNorm1d(84)
        self.fc3   = nn.Linear(84, 10)
        
        # self._initialize_weights()

    def forward(self, x):
        # out = F.relu(self.conv1(x))
        # out = F.max_pool2d(out, 2)
        # out = F.relu(self.conv2(out))
        # out = F.max_pool2d(out, 2)
        # out = out.view(out.size(0), -1)
        # out = F.relu(self.fc1(out))
        # out = F.relu(self.fc2(out))
        # out = self.fc3(out)
        # return out


        # out = F.relu(self.conv1(x))
        # out = self.norm1(out)
        # out = F.max_pool2d(out, 2)
        # out = F.relu(self.conv2(out))
        # out = self.norm2(out)
        # out = F.max_pool2d(out, 2)
        # out = out.view(out.size(0), -1)
        # out = F.relu(self.fc1(out))
        # out = self.norm3(out)
        # out = F.relu(self.fc2(out))
        # out = self.norm4(out)
        # out = self.fc3(out)
        # return out

        # out = swish(self.conv1(x))
        # out = F.max_pool2d(out, 2)
        # out = swish(self.conv2(out))
        # out = F.max_pool2d(out, 2)
        # out = out.view(out.size(0), -1)
        # out = swish(self.fc1(out))
        # out = swish(self.fc2(out))
        # out = self.fc3(out)
        # return out



        out = swish(self.conv1(x))
        out = self.norm1(out)
        out = F.max_pool2d(out, 2)
        out = swish(self.conv2(out))
        out = self.norm2(out)
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = swish(self.fc1(out))
        out = self.norm3(out)
        out = swish(self.fc2(out))
        out = self.norm4(out)
        out = self.fc3(out)
        return out

    """
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * (m.in_channels + m.out_channels)
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                n = m.weight.size(1)
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_() """

# %% [markdown]
# ### Step 1: Setting up preprocessing functions.
# Preprocessing is very important because it prepares your data for proceeding training steps.
# Write functions to load dataset and preprocess the incoming data. We recommend that the preprocess scheme \textbf{must} include normalize, standardization, batch shuffling to make sure the training
# process goes smoothly. The preprocess scheme may also contain some data augmentation methods
# (e.g., random crop, random flip, etc.).
#
# Reference value for mean/std:
#
# **mean(RGB-format): (0.4914, 0.4822, 0.4465)**
#
# **std(RGB-format): (0.2023, 0.1994, 0.2010)**

# %%
# Specify preprocessing function.
# Reference mean/std value for 
transform_train  = transforms.Compose([
        transforms.RandomHorizontalFlip(),
         transforms.RandomCrop(size=[32,32],padding=0,pad_if_needed=True,padding_mode='constant'),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

transform_val = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(size=[32,32],padding=0,pad_if_needed=True,padding_mode='constant'),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

# %% [markdown]
# ### Step 2: Setting up data I/O
# Data I/O reads data from the dataset and prepares it for further procedures. Note that you have to link transformation with data I/O so that these operations can be interleaved. Thus, the training process can be more efficient.

# %%
# You cannot change this line.
from tools.dataloader import CIFAR10
# Call the dataset Loader
DATAROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=4)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=4)
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F20.zip
# Extracting ./data/cifar10_trainval_F20.zip to ./data
# Files already downloaded and verified
# Training dataset has 45000 examples!
# Using downloaded and verified file: ./data/cifar10_trainval_F20.zip
# Extracting ./data/cifar10_trainval_F20.zip to ./data
# Files already downloaded and verified
# Validation dataset has 5000 examples!

# %% [markdown]
# ### Step 3: Instantialize your LeNet-5 model and deploy it to GPU devices.
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = LeNet5()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %% [markdown]
# ### Hyperparameter settings
# Hyperparameters are quite crucial in determining the performance of our model. The default hyperparameter settings are sufficient for a decent result. You may tune them wisely and carefully for better results.

# %%
# Initial learning rate

# INITIAL_LR = 1
lr_list=[1.0, 0.1, 0.05, 0.02, 0.01, 0.005, 0.002, 0.001]
INITIAL_LR = 0.01

wd_list=[0.01, 0.001, 0.0001, 0.00001, 0.0]
# Momentum for optimizer.
MOMENTUM = 0.9
# Regularization
# REG = 1e-4
REG = wd_list[4]
print(REG)
# Total number of training epochs
EPOCHS = 100
# Learning rate decay policy.
DECAY_EPOCHS = 2
DECAY = 1.00
# Out:
# 0.0

# %% [markdown]
# ### Handling weights load/save protocols.
# This handles the weight loading/saving protocols.You may be able to load from checkpoints.

# %%
CHECKPOINT_PATH = "./saved_model"
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = True
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Training from scratch ...
# Starting from learning rate 0.010000:

# %% [markdown]
# ### Step 4 Setting up loss functions and Optimizers
# Loss function is your objective to train the neural networks. Typically, we use multi-class cross entropy as objectives for classification models (e.g., CIFAR-10, MNIST). In this homework, we use SGD optimizer with momentum as our optimizer. You need to formulate the cross-entropy loss function in PyTorch.
# You should also specify a PyTorch Optimizer to optimize this loss function.

# %%
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
# optimizer = optim.SGD(params=net.parameters(), lr=current_learning_rate, momentum=MOMENTUM, weight_decay=REG, nesterov=False)
optimizer = optim.SGD(params=net.parameters(), lr=current_learning_rate, momentum=MOMENTUM,  nesterov=False)

# %% [markdown]
# ### Step 5: Start the training process.
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
# Training a neural network usually composes the following 3 parts:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU)**
#
# **ii) Do a forward pass to get the output logits from the neural network. Compute the forward loss.**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# You will also need to compute accuracy within all these parts to justify that your model is doing well on the dataset.

# %%
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
global_step = 0
best_val_acc = 0
bestnet = deepcopy(net)
for i in range(start_epoch, EPOCHS):
    print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    
    # Train the training dataset for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        l1_regularization = 0.
        for param in net.parameters():
            l1_regularization += param.abs().sum()
        loss = criterion(outputs, targets) + (1e-4)*l1_regularization
        # loss = criterion(outputs, targets)
#         if i==0:
#             print('initial loss: ',loss)
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        total_examples += predicted.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        train_loss += loss
        global_step += 1
                
    avg_loss = train_loss / (batch_idx + 1)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            l1_regularization = 0.
            for param in net.parameters():
                l1_regularization += param.abs().sum()
            loss = criterion(outputs, targets) + (1e-4)*l1_regularization
            # loss = criterion(outputs, targets)            
            # Calculate predicted labels
            _, predicted = outputs.max(1)
            total_examples += predicted.size(0)
            correct_examples += predicted.eq(targets).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

    # Handle the learning rate scheduler.
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        bestnet = deepcopy(net)
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
print("best val",best_val_acc)
# Out:
# 09-19 17:05:44.831521
# Validation...
# Validation loss: 1.2429, Validation accuracy: 0.6296
# Current learning rate has decayed to 0.010000
# Saving ...
# 2020-09-19 17:05:45.492809
# Epoch 3:
# Training loss: 1.1686, Training accuracy: 0.6553
# 2020-09-19 17:05:49.440400
# Validation...
# Validation loss: 1.2302, Validation accuracy: 0.6320
# Saving ...
# 2020-09-19 17:05:50.116126
# Epoch 4:
# Training loss: 1.1211, Training accuracy: 0.6737
# 2020-09-19 17:05:54.072104
# Validation...
# Validation loss: 1.1610, Validation accuracy: 0.6556
# Current learning rate has decayed to 0.010000
# Saving ...
# 2020-09-19 17:05:54.714474
# Epoch 5:
# Training loss: 1.0724, Training accuracy: 0.6940
# 2020-09-19 17:05:58.595133
# Validation...
# Validation loss: 1.1176, Validation accuracy: 0.6804
# Saving ...
# 2020-09-19 17:05:59.224679
# Epoch 6:
# Training loss: 1.0463, Training accuracy: 0.7046
# 2020-09-19 17:06:03.078290
# Validation...
# Validation loss: 1.1184, Validation accuracy: 0.6852
# Current learning rate has decayed to 0.010000
# Saving ...
# 2020-09-19 17:06:03.750754
# Epoch 7:
# Training loss: 1.0201, Training accuracy: 0.7130
# 2020-09-19 17:06:07.582559
# Validation...
# Validation loss: 1.1015, Validation accuracy: 0.6870
# Saving ...
# 2020-09-19 17:06:08.213421
# Epoch 8:
# Training loss: 1.0079, Training accuracy: 0.7185
# 2020-09-19 17:06:12.114661
# Validation...
# Validation loss: 1.0937, Validation accuracy: 0.6978
# Current learning rate has decayed to 0.010000
# Saving ...
# 2020-09-19 17:06:12.783967
# Epoch 9:
# Training loss: 0.9846, Training accuracy: 0.7292
# 2020-09-19 17:06:16.610894
# Validation...
# Validation loss: 1.0801, Validation accuracy: 0.6978
# 2020-09-19 17:06:17.215565
# Epoch 10:
# Training loss: 0.9737, Training accuracy: 0.7329
# 2020-09-19 17:06:21.089939
# Validation...
# Validation loss: 1.1118, Validation accuracy: 0.6908
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:06:21.692058
# Epoch 11:
# Training loss: 0.9593, Training accuracy: 0.7391
# 2020-09-19 17:06:25.714374
# Validation...
# Validation loss: 1.1225, Validation accuracy: 0.6856
# 2020-09-19 17:06:26.399553
# Epoch 12:
# Training loss: 0.9553, Training accuracy: 0.7412
# 2020-09-19 17:06:30.246838
# Validation...
# Validation loss: 1.0935, Validation accuracy: 0.7044
# Current learning rate has decayed to 0.010000
# Saving ...
# 2020-09-19 17:06:30.893764
# Epoch 13:
# Training loss: 0.9419, Training accuracy: 0.7492
# 2020-09-19 17:06:35.262460
# Validation...
# Validation loss: 1.0870, Validation accuracy: 0.7030
# 2020-09-19 17:06:35.874963
# Epoch 14:
# Training loss: 0.9347, Training accuracy: 0.7500
# 2020-09-19 17:06:39.887227
# Validation...
# Validation loss: 1.1134, Validation accuracy: 0.6902
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:06:40.552631
# Epoch 15:
# Training loss: 0.9273, Training accuracy: 0.7543
# 2020-09-19 17:06:44.472235
# Validation...
# Validation loss: 1.0830, Validation accuracy: 0.7072
# Saving ...
# 2020-09-19 17:06:45.101539
# Epoch 16:
# Training loss: 0.9101, Training accuracy: 0.7634
# 2020-09-19 17:06:48.967938
# Validation...
# Validation loss: 1.0918, Validation accuracy: 0.7120
# Current learning rate has decayed to 0.010000
# Saving ...
# 2020-09-19 17:06:49.565328
# Epoch 17:
# Training loss: 0.9162, Training accuracy: 0.7610
# 2020-09-19 17:06:53.469352
# Validation...
# Validation loss: 1.0917, Validation accuracy: 0.7018
# 2020-09-19 17:06:54.056268
# Epoch 18:
# Training loss: 0.9083, Training accuracy: 0.7651
# 2020-09-19 17:06:57.993262
# Validation...
# Validation loss: 1.0975, Validation accuracy: 0.7018
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:06:58.623440
# Epoch 19:
# Training loss: 0.9009, Training accuracy: 0.7693
# 2020-09-19 17:07:02.475532
# Validation...
# Validation loss: 1.0853, Validation accuracy: 0.7144
# Saving ...
# 2020-09-19 17:07:03.135308
# Epoch 20:
# Training loss: 0.9010, Training accuracy: 0.7694
# 2020-09-19 17:07:06.995096
# Validation...
# Validation loss: 1.0762, Validation accuracy: 0.7170
# Current learning rate has decayed to 0.010000
# Saving ...
# 2020-09-19 17:07:07.614087
# Epoch 21:
# Training loss: 0.8954, Training accuracy: 0.7711
# 2020-09-19 17:07:11.465980
# Validation...
# Validation loss: 1.1217, Validation accuracy: 0.7086
# 2020-09-19 17:07:12.108615
# Epoch 22:
# Training loss: 0.8888, Training accuracy: 0.7754
# 2020-09-19 17:07:15.993801
# Validation...
# Validation loss: 1.1316, Validation accuracy: 0.7048
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:07:16.614122
# Epoch 23:
# Training loss: 0.8867, Training accuracy: 0.7770
# 2020-09-19 17:07:20.453231
# Validation...
# Validation loss: 1.1074, Validation accuracy: 0.7132
# 2020-09-19 17:07:21.133631
# Epoch 24:
# Training loss: 0.8838, Training accuracy: 0.7802
# 2020-09-19 17:07:25.074128
# Validation...
# Validation loss: 1.1280, Validation accuracy: 0.7070
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:07:25.719493
# Epoch 25:
# Training loss: 0.8762, Training accuracy: 0.7830
# 2020-09-19 17:07:29.531431
# Validation...
# Validation loss: 1.1042, Validation accuracy: 0.7156
# 2020-09-19 17:07:30.150009
# Epoch 26:
# Training loss: 0.8777, Training accuracy: 0.7834
# 2020-09-19 17:07:34.065898
# Validation...
# Validation loss: 1.1102, Validation accuracy: 0.7120
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:07:34.692507
# Epoch 27:
# Training loss: 0.8721, Training accuracy: 0.7851
# 2020-09-19 17:07:38.543220
# Validation...
# Validation loss: 1.1270, Validation accuracy: 0.7126
# 2020-09-19 17:07:39.222589
# Epoch 28:
# Training loss: 0.8680, Training accuracy: 0.7872
# 2020-09-19 17:07:43.051932
# Validation...
# Validation loss: 1.1282, Validation accuracy: 0.7114
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:07:43.662022
# Epoch 29:
# Training loss: 0.8657, Training accuracy: 0.7887
# 2020-09-19 17:07:47.563261
# Validation...
# Validation loss: 1.1418, Validation accuracy: 0.7104
# 2020-09-19 17:07:48.163788
# Epoch 30:
# Training loss: 0.8679, Training accuracy: 0.7893
# 2020-09-19 17:07:52.182722
# Validation...
# Validation loss: 1.1327, Validation accuracy: 0.7176
# Current learning rate has decayed to 0.010000
# Saving ...
# 2020-09-19 17:07:52.856098
# Epoch 31:
# Training loss: 0.8640, Training accuracy: 0.7894
# 2020-09-19 17:07:56.757145
# Validation...
# Validation loss: 1.1499, Validation accuracy: 0.7054
# 2020-09-19 17:07:57.374644
# Epoch 32:
# Training loss: 0.8609, Training accuracy: 0.7924
# 2020-09-19 17:08:01.430772
# Validation...
# Validation loss: 1.1340, Validation accuracy: 0.7172
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:08:02.048394
# Epoch 33:
# Training loss: 0.8584, Training accuracy: 0.7955
# 2020-09-19 17:08:06.060094
# Validation...
# Validation loss: 1.1547, Validation accuracy: 0.7094
# 2020-09-19 17:08:06.658482
# Epoch 34:
# Training loss: 0.8571, Training accuracy: 0.7954
# 2020-09-19 17:08:10.662614
# Validation...
# Validation loss: 1.1608, Validation accuracy: 0.7110
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:08:11.282544
# Epoch 35:
# Training loss: 0.8606, Training accuracy: 0.7956
# 2020-09-19 17:08:15.185798
# Validation...
# Validation loss: 1.1319, Validation accuracy: 0.7192
# Saving ...
# 2020-09-19 17:08:15.821312
# Epoch 36:
# Training loss: 0.8546, Training accuracy: 0.7980
# 2020-09-19 17:08:19.717178
# Validation...
# Validation loss: 1.1719, Validation accuracy: 0.7124
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:08:20.350902
# Epoch 37:
# Training loss: 0.8494, Training accuracy: 0.7991
# 2020-09-19 17:08:24.356566
# Validation...
# Validation loss: 1.1452, Validation accuracy: 0.7170
# 2020-09-19 17:08:25.030678
# Epoch 38:
# Training loss: 0.8526, Training accuracy: 0.8013
# 2020-09-19 17:08:28.850325
# Validation...
# Validation loss: 1.1913, Validation accuracy: 0.7024
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:08:29.463282
# Epoch 39:
# Training loss: 0.8467, Training accuracy: 0.8018
# 2020-09-19 17:08:33.286735
# Validation...
# Validation loss: 1.1858, Validation accuracy: 0.7092
# 2020-09-19 17:08:33.919106
# Epoch 40:
# Training loss: 0.8480, Training accuracy: 0.8039
# 2020-09-19 17:08:37.750831
# Validation...
# Validation loss: 1.1664, Validation accuracy: 0.7158
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:08:38.350908
# Epoch 41:
# Training loss: 0.8443, Training accuracy: 0.8028
# 2020-09-19 17:08:42.202651
# Validation...
# Validation loss: 1.1852, Validation accuracy: 0.7088
# 2020-09-19 17:08:42.848642
# Epoch 42:
# Training loss: 0.8366, Training accuracy: 0.8076
# 2020-09-19 17:08:46.708848
# Validation...
# Validation loss: 1.1923, Validation accuracy: 0.7124
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:08:47.345819
# Epoch 43:
# Training loss: 0.8390, Training accuracy: 0.8066
# 2020-09-19 17:08:51.683184
# Validation...
# Validation loss: 1.1985, Validation accuracy: 0.7036
# 2020-09-19 17:08:52.361920
# Epoch 44:
# Training loss: 0.8378, Training accuracy: 0.8071
# 2020-09-19 17:08:56.368617
# Validation...
# Validation loss: 1.1888, Validation accuracy: 0.7154
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:08:57.027685
# Epoch 45:
# Training loss: 0.8359, Training accuracy: 0.8098
# 2020-09-19 17:09:01.023634
# Validation...
# Validation loss: 1.1909, Validation accuracy: 0.7092
# 2020-09-19 17:09:01.672560
# Epoch 46:
# Training loss: 0.8373, Training accuracy: 0.8093
# 2020-09-19 17:09:05.617419
# Validation...
# Validation loss: 1.1935, Validation accuracy: 0.7132
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:09:06.233848
# Epoch 47:
# Training loss: 0.8361, Training accuracy: 0.8092
# 2020-09-19 17:09:10.113567
# Validation...
# Validation loss: 1.1787, Validation accuracy: 0.7150
# 2020-09-19 17:09:10.691814
# Epoch 48:
# Training loss: 0.8356, Training accuracy: 0.8114
# 2020-09-19 17:09:14.513685
# Validation...
# Validation loss: 1.2054, Validation accuracy: 0.7114
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:09:15.184394
# Epoch 49:
# Training loss: 0.8344, Training accuracy: 0.8118
# 2020-09-19 17:09:19.201377
# Validation...
# Validation loss: 1.1959, Validation accuracy: 0.7084
# 2020-09-19 17:09:19.840348
# Epoch 50:
# Training loss: 0.8317, Training accuracy: 0.8127
# 2020-09-19 17:09:23.678234
# Validation...
# Validation loss: 1.2053, Validation accuracy: 0.7100
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:09:24.297634
# Epoch 51:
# Training loss: 0.8319, Training accuracy: 0.8142
# 2020-09-19 17:09:28.492488
# Validation...
# Validation loss: 1.2215, Validation accuracy: 0.7096
# 2020-09-19 17:09:29.159537
# Epoch 52:
# Training loss: 0.8262, Training accuracy: 0.8161
# 2020-09-19 17:09:33.011016
# Validation...
# Validation loss: 1.2098, Validation accuracy: 0.7118
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:09:33.670703
# Epoch 53:
# Training loss: 0.8305, Training accuracy: 0.8155
# 2020-09-19 17:09:38.040025
# Validation...
# Validation loss: 1.2038, Validation accuracy: 0.7130
# 2020-09-19 17:09:38.719559
# Epoch 54:
# Training loss: 0.8311, Training accuracy: 0.8131
# 2020-09-19 17:09:42.665289
# Validation...
# Validation loss: 1.2450, Validation accuracy: 0.7060
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:09:43.297828
# Epoch 55:
# Training loss: 0.8147, Training accuracy: 0.8222
# 2020-09-19 17:09:47.240029
# Validation...
# Validation loss: 1.2119, Validation accuracy: 0.7198
# Saving ...
# 2020-09-19 17:09:48.015835
# Epoch 56:
# Training loss: 0.8233, Training accuracy: 0.8189
# 2020-09-19 17:09:51.948273
# Validation...
# Validation loss: 1.2451, Validation accuracy: 0.7072
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:09:52.599001
# Epoch 57:
# Training loss: 0.8225, Training accuracy: 0.8196
# 2020-09-19 17:09:56.631335
# Validation...
# Validation loss: 1.2334, Validation accuracy: 0.7084
# 2020-09-19 17:09:57.277273
# Epoch 58:
# Training loss: 0.8209, Training accuracy: 0.8193
# 2020-09-19 17:10:01.234170
# Validation...
# Validation loss: 1.2584, Validation accuracy: 0.7038
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:10:01.875914
# Epoch 59:
# Training loss: 0.8172, Training accuracy: 0.8216
# 2020-09-19 17:10:05.745505
# Validation...
# Validation loss: 1.2414, Validation accuracy: 0.7128
# 2020-09-19 17:10:06.385997
# Epoch 60:
# Training loss: 0.8165, Training accuracy: 0.8207
# 2020-09-19 17:10:10.283417
# Validation...
# Validation loss: 1.2404, Validation accuracy: 0.7078
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:10:10.916166
# Epoch 61:
# Training loss: 0.8236, Training accuracy: 0.8215
# 2020-09-19 17:10:14.793859
# Validation...
# Validation loss: 1.2660, Validation accuracy: 0.7060
# 2020-09-19 17:10:15.413756
# Epoch 62:
# Training loss: 0.8222, Training accuracy: 0.8227
# 2020-09-19 17:10:19.309896
# Validation...
# Validation loss: 1.2437, Validation accuracy: 0.7066
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:10:19.938199
# Epoch 63:
# Training loss: 0.8209, Training accuracy: 0.8212
# 2020-09-19 17:10:23.775642
# Validation...
# Validation loss: 1.2651, Validation accuracy: 0.7062
# 2020-09-19 17:10:24.382487
# Epoch 64:
# Training loss: 0.8185, Training accuracy: 0.8229
# 2020-09-19 17:10:28.329133
# Validation...
# Validation loss: 1.2456, Validation accuracy: 0.7136
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:10:28.983465
# Epoch 65:
# Training loss: 0.8151, Training accuracy: 0.8239
# 2020-09-19 17:10:32.869576
# Validation...
# Validation loss: 1.2477, Validation accuracy: 0.7098
# 2020-09-19 17:10:33.549682
# Epoch 66:
# Training loss: 0.8130, Training accuracy: 0.8236
# 2020-09-19 17:10:37.584080
# Validation...
# Validation loss: 1.2385, Validation accuracy: 0.7170
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:10:38.223995
# Epoch 67:
# Training loss: 0.8168, Training accuracy: 0.8232
# 2020-09-19 17:10:42.145237
# Validation...
# Validation loss: 1.2932, Validation accuracy: 0.7078
# 2020-09-19 17:10:42.767760
# Epoch 68:
# Training loss: 0.8163, Training accuracy: 0.8275
# 2020-09-19 17:10:46.707850
# Validation...
# Validation loss: 1.2542, Validation accuracy: 0.7082
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:10:47.405160
# Epoch 69:
# Training loss: 0.8123, Training accuracy: 0.8266
# 2020-09-19 17:10:51.333137
# Validation...
# Validation loss: 1.2818, Validation accuracy: 0.7074
# 2020-09-19 17:10:52.024993
# Epoch 70:
# Training loss: 0.8107, Training accuracy: 0.8280
# 2020-09-19 17:10:55.848958
# Validation...
# Validation loss: 1.2794, Validation accuracy: 0.7098
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:10:56.455279
# Epoch 71:
# Training loss: 0.8146, Training accuracy: 0.8256
# 2020-09-19 17:11:00.435247
# Validation...
# Validation loss: 1.2756, Validation accuracy: 0.7070
# 2020-09-19 17:11:01.125984
# Epoch 72:
# Training loss: 0.8096, Training accuracy: 0.8281
# 2020-09-19 17:11:05.030889
# Validation...
# Validation loss: 1.2937, Validation accuracy: 0.7044
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:11:05.692161
# Epoch 73:
# Training loss: 0.8091, Training accuracy: 0.8299
# 2020-09-19 17:11:09.602861
# Validation...
# Validation loss: 1.3126, Validation accuracy: 0.7040
# 2020-09-19 17:11:10.264732
# Epoch 74:
# Training loss: 0.8086, Training accuracy: 0.8301
# 2020-09-19 17:11:14.131156
# Validation...
# Validation loss: 1.2613, Validation accuracy: 0.7078
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:11:14.768078
# Epoch 75:
# Training loss: 0.8104, Training accuracy: 0.8306
# 2020-09-19 17:11:18.636097
# Validation...
# Validation loss: 1.2764, Validation accuracy: 0.7124
# 2020-09-19 17:11:19.247955
# Epoch 76:
# Training loss: 0.8021, Training accuracy: 0.8315
# 2020-09-19 17:11:23.205911
# Validation...
# Validation loss: 1.2892, Validation accuracy: 0.7084
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:11:23.814751
# Epoch 77:
# Training loss: 0.8093, Training accuracy: 0.8299
# 2020-09-19 17:11:27.687644
# Validation...
# Validation loss: 1.3022, Validation accuracy: 0.7046
# 2020-09-19 17:11:28.295692
# Epoch 78:
# Training loss: 0.8067, Training accuracy: 0.8314
# 2020-09-19 17:11:32.577411
# Validation...
# Validation loss: 1.3006, Validation accuracy: 0.7068
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:11:33.226561
# Epoch 79:
# Training loss: 0.8087, Training accuracy: 0.8303
# 2020-09-19 17:11:37.128769
# Validation...
# Validation loss: 1.2911, Validation accuracy: 0.7064
# 2020-09-19 17:11:37.725248
# Epoch 80:
# Training loss: 0.8081, Training accuracy: 0.8304
# 2020-09-19 17:11:41.606411
# Validation...
# Validation loss: 1.3003, Validation accuracy: 0.6964
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:11:42.216326
# Epoch 81:
# Training loss: 0.8109, Training accuracy: 0.8308
# 2020-09-19 17:11:46.174909
# Validation...
# Validation loss: 1.3046, Validation accuracy: 0.7062
# 2020-09-19 17:11:46.760512
# Epoch 82:
# Training loss: 0.8026, Training accuracy: 0.8327
# 2020-09-19 17:11:50.692355
# Validation...
# Validation loss: 1.3010, Validation accuracy: 0.7064
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:11:51.365624
# Epoch 83:
# Training loss: 0.8036, Training accuracy: 0.8330
# 2020-09-19 17:11:55.193469
# Validation...
# Validation loss: 1.3400, Validation accuracy: 0.7008
# 2020-09-19 17:11:55.806973
# Epoch 84:
# Training loss: 0.8044, Training accuracy: 0.8332
# 2020-09-19 17:11:59.944433
# Validation...
# Validation loss: 1.3026, Validation accuracy: 0.7054
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:12:00.603159
# Epoch 85:
# Training loss: 0.8045, Training accuracy: 0.8340
# 2020-09-19 17:12:04.489602
# Validation...
# Validation loss: 1.3245, Validation accuracy: 0.7050
# 2020-09-19 17:12:05.144094
# Epoch 86:
# Training loss: 0.8057, Training accuracy: 0.8339
# 2020-09-19 17:12:09.010074
# Validation...
# Validation loss: 1.2959, Validation accuracy: 0.7000
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:12:09.655206
# Epoch 87:
# Training loss: 0.8022, Training accuracy: 0.8356
# 2020-09-19 17:12:13.490150
# Validation...
# Validation loss: 1.3509, Validation accuracy: 0.6914
# 2020-09-19 17:12:14.074454
# Epoch 88:
# Training loss: 0.7957, Training accuracy: 0.8380
# 2020-09-19 17:12:17.971939
# Validation...
# Validation loss: 1.2707, Validation accuracy: 0.7172
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:12:18.606344
# Epoch 89:
# Training loss: 0.7967, Training accuracy: 0.8370
# 2020-09-19 17:12:22.613885
# Validation...
# Validation loss: 1.3242, Validation accuracy: 0.7042
# 2020-09-19 17:12:23.312520
# Epoch 90:
# Training loss: 0.8006, Training accuracy: 0.8384
# 2020-09-19 17:12:27.345408
# Validation...
# Validation loss: 1.2855, Validation accuracy: 0.7092
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:12:27.962527
# Epoch 91:
# Training loss: 0.7927, Training accuracy: 0.8394
# 2020-09-19 17:12:31.782326
# Validation...
# Validation loss: 1.3030, Validation accuracy: 0.7018
# 2020-09-19 17:12:32.456617
# Epoch 92:
# Training loss: 0.7983, Training accuracy: 0.8376
# 2020-09-19 17:12:36.399100
# Validation...
# Validation loss: 1.3018, Validation accuracy: 0.7096
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:12:37.065977
# Epoch 93:
# Training loss: 0.7974, Training accuracy: 0.8381
# 2020-09-19 17:12:41.112874
# Validation...
# Validation loss: 1.3460, Validation accuracy: 0.7032
# 2020-09-19 17:12:41.749335
# Epoch 94:
# Training loss: 0.7997, Training accuracy: 0.8380
# 2020-09-19 17:12:46.145329
# Validation...
# Validation loss: 1.3184, Validation accuracy: 0.7110
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:12:46.765146
# Epoch 95:
# Training loss: 0.8042, Training accuracy: 0.8362
# 2020-09-19 17:12:50.648714
# Validation...
# Validation loss: 1.3390, Validation accuracy: 0.7022
# 2020-09-19 17:12:51.300276
# Epoch 96:
# Training loss: 0.8023, Training accuracy: 0.8371
# 2020-09-19 17:12:55.302802
# Validation...
# Validation loss: 1.3646, Validation accuracy: 0.7066
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:12:55.951276
# Epoch 97:
# Training loss: 0.7938, Training accuracy: 0.8402
# 2020-09-19 17:12:59.813971
# Validation...
# Validation loss: 1.3580, Validation accuracy: 0.7046
# 2020-09-19 17:13:00.441260
# Epoch 98:
# Training loss: 0.7991, Training accuracy: 0.8379
# 2020-09-19 17:13:04.402277
# Validation...
# Validation loss: 1.3358, Validation accuracy: 0.7002
# Current learning rate has decayed to 0.010000
# 2020-09-19 17:13:05.064859
# Epoch 99:
# Training loss: 0.8008, Training accuracy: 0.8360
# 2020-09-19 17:13:08.952005
# Validation...
# Validation loss: 1.3343, Validation accuracy: 0.6960
# Optimization finished.
# best val 0.7198

# %%
import matplotlib.pyplot as plt
for name, module in net.named_modules():
    if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
        # Get the weight of the module as a NumPy array
        weight = module.weight.detach().cpu().numpy()
        
        # Reshape for histogram
        weight = weight.reshape(-1)
        _ = plt.hist(weight, bins=20)
        plt.title("Weight histogram of layer "+name)
        plt.show()
